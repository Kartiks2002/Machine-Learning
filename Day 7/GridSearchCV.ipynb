# %% [markdown]
# ## Regression with GridSearchCV Concrete Data

# %%
import pandas as pd
df = pd.read_csv('../Cases/Concrete Strength/Concrete_Data.csv')
df.head(1)
# Out:
#    Cement  Blast  Fly  Water  Superplasticizer  Coarse   Fine  Age  Strength
# 0   540.0    0.0  0.0  162.0               2.5  1040.0  676.0   28     79.99

# %%
X, y = df.drop(columns=['Strength']), df['Strength']

# %% [markdown]
# #### With scaler as StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import Pipeline

scaler = StandardScaler()
knn = KNeighborsRegressor()
kfold = KFold(n_splits=5, shuffle=True, random_state=24)
pipe = Pipeline(
    [
        ('SCL', scaler),
        ('KNN', knn)
    ]
    
)
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('SCL', StandardScaler()), ('KNN', KNeighborsRegressor())],
#  'verbose': False,
#  'SCL': StandardScaler(),
#  'KNN': KNeighborsRegressor(),
#  'SCL__copy': True,
#  'SCL__with_mean': True,
#  'SCL__with_std': True,
#  'KNN__algorithm': 'auto',
#  'KNN__leaf_size': 30,
#  'KNN__metric': 'minkowski',
#  'KNN__metric_params': None,
#  'KNN__n_jobs': None,
#  'KNN__n_neighbors': 5,
#  'KNN__p': 2,
#  'KNN__weights': 'uniform'}

# %%
params = {'KNN__n_neighbors': [1,2,3,4,5,6,7,8]}
gcv_knn = GridSearchCV(pipe, param_grid=params, cv=kfold, scoring='r2')
gcv_knn.fit(X, y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', StandardScaler()),
#                                        ('KNN', KNeighborsRegressor())]),
#              param_grid={'KNN__n_neighbors': [1, 2, 3, 4, 5, 6, 7, 8]},
#              scoring='r2')

# %%
print(gcv_knn.best_params_)
print(gcv_knn.best_score_)
# Out:
# {'KNN__n_neighbors': 3}
# 0.7162924205032816

# %% [markdown]
# #### With scaler as MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import Pipeline

scaler = MinMaxScaler()
knn = KNeighborsRegressor()
kfold = KFold(n_splits=5, shuffle=True, random_state=24)
pipe = Pipeline(
    [
        ('SCL', scaler),
        ('KNN', knn)
    ]
    
)
params = {'KNN__n_neighbors': [1,2,3,4,5,6,7,8]}
gcv_knn = GridSearchCV(pipe, param_grid=params, cv=kfold, scoring='r2')
gcv_knn.fit(X, y)
print(gcv_knn.best_params_)
print(gcv_knn.best_score_)
# Out:
# {'KNN__n_neighbors': 5}
# 0.6938854701543569

# %% [markdown]
# #### Without Scaling

# %%
params = {'n_neighbors': [1,2,3,4,5,6,7,8]}
knn = KNeighborsRegressor()
gcv_knn = GridSearchCV(knn, param_grid=params, cv=kfold, scoring='r2')
gcv_knn.fit(X, y)
print(gcv_knn.best_params_)
print(gcv_knn.best_score_)
# Out:
# {'n_neighbors': 3}
# 0.7046900509877506

# %% [markdown]
# #### Combining Scalers with the GridSearch

# %%
scl_std, scl_mm = StandardScaler(), MinMaxScaler()
knn = KNeighborsRegressor()

pipe = Pipeline(
    [
        ('SCL', None),
        ('KNN', knn)
    ]
    
)

params = {'KNN__n_neighbors': [1,2,3,4,5,6,7,8],
         'SCL' : [None, scl_std, scl_mm]}
gcv_knn = GridSearchCV(pipe, param_grid=params, cv=kfold, scoring='r2')
gcv_knn.fit(X, y)
print(gcv_knn.best_params_)
print(gcv_knn.best_score_)
# Out:
# {'KNN__n_neighbors': 3, 'SCL': StandardScaler()}
# 0.7162924205032816

# %% [markdown]
# #### Standard Scaler is giving better r2 score, so we will use it for inferencing

# %%
test = pd.read_csv('../Cases/Concrete Strength/testConcrete.csv')
test.head(1)
# Out:
#    Cement  Blast  Fly  Water  Superplasticizer  Coarse  Fine  Age
# 0     495    120    0    155                 5     866   884   75

# %%
y_pred = gcv_knn.predict(test)
test['Strength'] = y_pred
# test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 y_pred = gcv_knn.predict(test)
#       2 test['Strength'] = y_pred
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:546, in BaseSearchCV.predict(self, X)
#     528 """Call predict on the estimator with the best found parameters.
#     529
#     530 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     543     the best found parameters.
#     544 """
#     545 check_is_fitted(self)
# --> 546 return self.best_estimator_.predict(X)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\pipeline.py:602, in Pipeline.predict(self, X, **params)
#     600 if not _routing_enabled():
#     601     for _, name, transform in self._iter(with_final=False):
# --> 602         Xt = transform.transform(Xt)
#     603     return self.steps[-1][1].predict(Xt, **params)
#     605 # metadata routing enabled
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:1043, in StandardScaler.transform(self, X, copy)
#    1040 check_is_fitted(self)
#    1042 copy = copy if copy is not None else self.copy
# -> 1043 X = self._validate_data(
#    1044     X,
#    1045     reset=False,
#    1046     accept_sparse="csr",
#    1047     copy=copy,
#    1048     dtype=FLOAT_DTYPES,
#    1049     force_all_finite="allow-nan",
#    1050 )
#    1052 if sparse.issparse(X):
#    1053     if self.with_mean:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Al
# - Ba
# - Ca
# - Fe
# - K
# - ...
# Feature names seen at fit time, yet now missing:
# - Age
# - Blast
# - Cement
# - Coarse
# - Fine
# - ...

# %%
df_cv = pd.DataFrame(gcv_lr.cv_results_)
df_cv

# %% [markdown]
# ## Classification with GridSearchCV Glass Identification

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('../Cases/Glass Identification/Glass.csv')
df.head(1)
# Out:
#         RI     Na    Mg   Al     Si     K    Ca   Ba   Fe  \
# 0  1.52101  13.64  4.49  1.1  71.78  0.06  8.75  0.0  0.0
#
#                                Type
# 0  building_windows_float_processed

# %%
X, y = df.drop('Type', axis=1), df['Type']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import Pipeline

scl_std, scl_mm = StandardScaler(), MinMaxScaler()
lr = LogisticRegression()

pipe = Pipeline(
    [
        ('SCL', None),
        ('LR', lr)
    ]
    
)
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('SCL', None), ('LR', LogisticRegression())],
#  'verbose': False,
#  'SCL': None,
#  'LR': LogisticRegression(),
#  'LR__C': 1.0,
#  'LR__class_weight': None,
#  'LR__dual': False,
#  'LR__fit_intercept': True,
#  'LR__intercept_scaling': 1,
#  'LR__l1_ratio': None,
#  'LR__max_iter': 100,
#  'LR__multi_class': 'auto',
#  'LR__n_jobs': None,
#  'LR__penalty': 'l2',
#  'LR__random_state': None,
#  'LR__solver': 'lbfgs',
#  'LR__tol': 0.0001,
#  'LR__verbose': 0,
#  'LR__warm_start': False}

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np
l1_ratio = np.linspace(0.001, 1, 5)

params = {'LR__penalty': ['l1', None, 'l2', 'elasticNet'],
          'LR__multi_class': ['ovr', 'multinomial'],
          'LR__l1_ratio': l1_ratio,
          'LR__solver': ['lbfgs', 'sag', 'saga', 'liblinear', 'newton-cg', 'newton-cholesky'],
         'SCL' : [None, scl_std, scl_mm]}
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
gcv_lr = GridSearchCV(pipe, param_grid=params, cv=kfold, scoring='accuracy')
gcv_lr.fit(X, y)
print(gcv_lr.best_params_)
print(gcv_lr.best_score_)
# Out:
# {'LR__l1_ratio': 0.001, 'LR__multi_class': 'ovr', 'LR__penalty': None, 'LR__solver': 'newton-cg', 'SCL': None}
# 0.6637873754152824

# %%
test = pd.read_csv('../Cases/Glass Identification/tst_Glass.csv')
y_pred = gcv_lr.predict(test)
test['Type'] = y_pred
test
# Out:
#        RI    Na    Mg    Al     Si      K    Ca    Ba     Fe  \
# 0  1.5321  14.0  0.00  0.34  70.23  0.001   6.7  1.23  0.000
# 1  1.5212  15.0  3.00  1.23  75.90  0.100   7.0  0.00  0.440
# 2  1.5112  13.0  3.50  2.30  73.00  3.400  14.0  2.30  0.220
# 3  1.5000  12.4  1.23  3.22  74.22  4.500  10.0  3.10  0.100
# 4  1.5200  13.0  2.40  0.34  71.22  3.200   9.0  1.44  0.001
# 5  1.5100  16.0  2.70  4.00  70.00  2.000   6.0  2.90  0.890
#
#                                    Type
# 0  building_windows_non_float_processed
# 1      building_windows_float_processed
# 2      building_windows_float_processed
# 3      building_windows_float_processed
# 4      building_windows_float_processed
# 5      building_windows_float_processed

# %%
df_cv = pd.DataFrame(gcv_lr.cv_results_)
df_cv
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.000999  5.135693e-07              0.0             0.0
# 1         0.002798  3.994704e-04              0.0             0.0
# 2         0.002199  3.999711e-04              0.0             0.0
# 3         0.000800  3.997803e-04              0.0             0.0
# 4         0.002586  4.797498e-04              0.0             0.0
# ..             ...           ...              ...             ...
# 715       0.002598  4.894536e-04              0.0             0.0
# 716       0.002598  4.894537e-04              0.0             0.0
# 717       0.000999  2.336015e-07              0.0             0.0
# 718       0.002798  3.995657e-04              0.0             0.0
# 719       0.002598  4.892590e-04              0.0             0.0
#
#     param_LR__l1_ratio param_LR__multi_class param_LR__penalty  \
# 0                0.001                   ovr                l1
# 1                0.001                   ovr                l1
# 2                0.001                   ovr                l1
# 3                0.001                   ovr                l1
# 4                0.001                   ovr                l1
# ..                 ...                   ...               ...
# 715                1.0           multinomial        elasticNet
# 716                1.0           multinomial        elasticNet
# 717                1.0           multinomial        elasticNet
# 718                1.0           multinomial        elasticNet
# 719                1.0           multinomial        elasticNet
#
#     param_LR__solver         param_SCL  \
# 0              lbfgs              None
# 1              lbfgs  StandardScaler()
# 2              lbfgs    MinMaxScaler()
# 3                sag              None
# 4                sag  StandardScaler()
# ..               ...               ...
# 715        newton-cg  StandardScaler()
# 716        newton-cg    MinMaxScaler()
# 717  newton-cholesky              None
# 718  newton-cholesky  StandardScaler()
# 719  newton-cholesky    MinMaxScaler()
#
#                                                 params  split0_test_score  \
# 0    {'LR__l1_ratio': 0.001, 'LR__multi_class': 'ov...                NaN
# 1    {'LR__l1_ratio': 0.001, 'LR__multi_class': 'ov...                NaN
# 2    {'LR__l1_ratio': 0.001, 'LR__multi_class': 'ov...                NaN
# 3    {'LR__l1_ratio': 0.001, 'LR__multi_class': 'ov...                NaN
# 4    {'LR__l1_ratio': 0.001, 'LR__multi_class': 'ov...                NaN
# ..                                                 ...                ...
# 715  {'LR__l1_ratio': 1.0, 'LR__multi_class': 'mult...                NaN
# 716  {'LR__l1_ratio': 1.0, 'LR__multi_class': 'mult...                NaN
# 717  {'LR__l1_ratio': 1.0, 'LR__multi_class': 'mult...                NaN
# 718  {'LR__l1_ratio': 1.0, 'LR__multi_class': 'mult...                NaN
# 719  {'LR__l1_ratio': 1.0, 'LR__multi_class': 'mult...                NaN
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 715                NaN                NaN                NaN
# 716                NaN                NaN                NaN
# 717                NaN                NaN                NaN
# 718                NaN                NaN                NaN
# 719                NaN                NaN                NaN
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                  NaN              NaN             NaN              331
# 1                  NaN              NaN             NaN              331
# 2                  NaN              NaN             NaN              331
# 3                  NaN              NaN             NaN              331
# 4                  NaN              NaN             NaN              331
# ..                 ...              ...             ...              ...
# 715                NaN              NaN             NaN              331
# 716                NaN              NaN             NaN              331
# 717                NaN              NaN             NaN              331
# 718                NaN              NaN             NaN              331
# 719                NaN              NaN             NaN              331
#
# [720 rows x 18 columns]
